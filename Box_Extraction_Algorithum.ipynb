# %%
def sort_contours(cnts, method="left-to-right"):
    # initialize the reverse flag and sort index
    reverse = False
    i = 0
    # handle if we need to sort in reverse
    if method == "right-to-left" or method == "bottom-to-top":
        reverse = True
        # handle if we are sorting against the y-coordinate rather than
        # the x-coordinate of the bounding box
    if method == "top-to-bottom" or method == "bottom-to-top":
        i = 1
        # construct the list of bounding boxes and sort them from top to
        # bottom
        boundingBoxes = [cv2.boundingRect(c) for c in cnts]
        (cnts, boundingBoxes) = zip(*sorted(zip(cnts, boundingBoxes),
                                            key=lambda b:b[1][i], reverse=reverse))
        # return the list of sorted contours and bounding boxes
        return (cnts, boundingBoxes)

# %%
def box_extraction(img_for_box_extraction_path, cropped_dir_path):
    img = cv2.imread(img_for_box_extraction_path, 0)  # Read the image
    
    (thresh, img_bin) = cv2.threshold(img, 120, 255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)  # Thresholding the image
    img_bin = 255-img_bin  # Invert the image
    cv2.imwrite("Image_bin.jpg",img_bin)
   
    # Defining a kernel length
    kernel_length = np.array(img).shape[1]//150
     
    # A verticle kernel of (1 X kernel_length), which will detect all the verticle lines from the image.
    verticle_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, kernel_length))
    # A horizontal kernel of (kernel_length X 1), which will help to detect all the horizontal line from the image.
    hori_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (kernel_length, 1))
    # A kernel of (3 X 3) ones.
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 2))
# Morphological operation to detect verticle lines from an image
    img_temp1 = cv2.erode(img_bin, verticle_kernel, iterations=3)
    verticle_lines_img = cv2.dilate(img_temp1, verticle_kernel, iterations=3)
    cv2.imwrite("verticle_lines.jpg",verticle_lines_img)
# Morphological operation to detect horizontal lines from an image
    img_temp2 = cv2.erode(img_bin, hori_kernel, iterations=3)
    horizontal_lines_img = cv2.dilate(img_temp2, hori_kernel, iterations=3)
    cv2.imwrite("horizontal_lines.jpg",horizontal_lines_img)
# Weighting parameters, this will decide the quantity of an image to be added to make a new image.
    alpha = 0.8
    beta = 5.0 - alpha
    # This function helps to add two image with specific weight parameter to get a third image as summation of two image.
    img_final_bin = cv2.addWeighted(verticle_lines_img, alpha, horizontal_lines_img, beta, 0.0)
    img_final_bin = cv2.erode(~img_final_bin, kernel, iterations=2)
    (thresh, img_final_bin) = cv2.threshold(img_final_bin, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
# For Debugging
    # Enable this line to see verticle and horizontal lines in the image which is used to find boxes
    cv2.imwrite("img_final_bin.jpg",img_final_bin)
    # Find contours for image, which will detect all the boxes
    contours, hierarchy = cv2.findContours(
        img_final_bin, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    # Sort all the contours by top to bottom.
    (contours, boundingBoxes) = sort_contours(contours, method="top-to-bottom")
    idx =300
    for c in contours:
        # Returns the location and width,height for every contour
        x, y, w, h = cv2.boundingRect(c)
# If the box height is greater then 20, widht is >80, then only save it as a box in "cropped/" folder.
        #if (w > 80 and h > 20) and w > 3*h:
        idx += 1
        new_img = img[y:y+h, x:x+w]
        cv2.imwrite(cropped_dir_path+str(idx) + '.jpg', new_img)
        print(cropped_dir_path+str(idx) + '.jpg')
box_extraction('C:\\Users\\mypc\\Desktop\\sperated\\boxes separated-034.jpg', "C:\\Users\\mypc\\Desktop\\sperated\\seperated from images\\")
# Out:
# C:\Users\mypc\Desktop\sperated\seperated from images\301.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\302.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\303.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\304.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\305.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\306.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\307.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\308.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\309.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\310.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\311.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\312.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\313.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\314.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\315.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\316.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\317.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\318.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\319.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\320.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\321.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\322.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\323.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\324.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\325.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\326.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\327.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\328.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\329.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\330.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\331.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\332.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\333.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\334.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\335.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\336.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\337.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\338.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\339.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\340.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\341.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\342.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\343.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\344.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\345.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\346.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\347.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\348.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\349.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\350.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\351.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\352.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\353.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\354.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\355.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\356.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\357.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\358.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\359.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\360.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\361.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\362.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\363.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\364.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\365.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\366.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\367.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\368.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\369.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\370.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\371.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\372.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\373.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\374.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\375.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\376.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\377.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\378.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\379.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\380.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\381.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\382.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\383.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\384.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\385.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\386.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\387.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\388.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\389.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\390.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\391.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\392.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\393.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\394.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\395.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\396.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\397.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\398.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\399.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\400.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\401.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\402.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\403.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\404.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\405.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\406.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\407.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\408.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\409.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\410.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\411.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\412.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\413.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\414.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\415.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\416.jpg
# C:\Users\mypc\Desktop\sperated\seperated from images\417.jpg
